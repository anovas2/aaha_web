# %%
import pandas as pd

# %%
df = pd.read_csv("project2housing.csv", encoding = "utf-8")
df.head()
# Out:
#    % Occupied  % Reported  % Extremely Low Income  % Female Head  \
# 0          78          93                      72             71
# 1          78          93                      72             71
# 2          78          93                      72             71
# 3          88          90                      84             85
# 4          88          90                      84             85
#
#    % in poverty (Census tract)  % minority (Census tract)  % Very Low Income  \
# 0                           21                         65                 96
# 1                           21                         65                 96
# 2                           21                         65                 96
# 3                           32                         67                 98
# 4                           32                         67                 98
#
#    % with disability among Head Spouse Co-head aged 61 years or less  \
# ...
