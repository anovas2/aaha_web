# %%
import pandas as pd
import json

# %%
df = pd.read_csv("project2housing.csv", encoding = "utf-8")
df
# Out:
#      % Occupied  % Reported  % Extremely Low Income  % Female Head  \
# 0            78          93                      72             71
# 1            78          93                      72             71
# 2            78          93                      72             71
# 3            88          90                      84             85
# 4            88          90                      84             85
# ..          ...         ...                     ...            ...
# 406          86          97                      77             67
# 407          92         100                      84             74
# 408          92         100                      84             74
# 409          81          95                      63             57
# 410          81          95                      63             57
#
#      % in poverty (Census tract)  % minority (Census tract)  \
# 0                             21                         65
# ...

# %%
df_json = df.to_json (r'project2housing_data.json', orient='split')
